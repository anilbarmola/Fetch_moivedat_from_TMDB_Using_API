# %%
import pandas as pd
import requests

# %%
# get API key and JSON data from TMDB website
#
#Api data =https://api.themoviedb.org/3/movie/top_rated?api_key=6f609c114c93ce1cf2e9cb21f4307890&language=en-US&page=1

# %%
data=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=6f609c114c93ce1cf2e9cb21f4307890&language=en-US&page=1")

# %%
#this is json data fetch from TMDB website
data.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 88.994,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 17053},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
# turn json into dataframe
df=pd.DataFrame(data.json()["results"])[["title","release_date","vote_average","vote_count"]]

# %%
df.head(5)
# Out:
#                             title release_date  vote_average  vote_count
# 0                   The Godfather   1972-03-14           8.7       17053
# 1        The Shawshank Redemption   1994-09-23           8.7       22826
# 2           The Godfather Part II   1974-12-20           8.6       10332
# 3  Guillermo del Toro's Pinocchio   2022-11-09           8.6         420
# 4               20th Century Girl   2022-10-06           8.6         317

# %%
temp_df=pd.DataFrame(data.json()["results"])[["title","release_date","vote_average","vote_count"]]

# %%
#appling a loop to get all the page data into one singe data frame
df2=pd.DataFrame()
for i in range (1,529):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(data.json()["results"])[["title","release_date","vote_average","vote_count"]]
    df2 = df2.append(temp_df,ignore_index=True)
# Out:
# /tmp/ipykernel_301/1128254610.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(temp_df,ignore_index=True)
# /tmp/ipykernel_301/1128254610.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(temp_df,ignore_index=True)
# /tmp/ipykernel_301/1128254610.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(temp_df,ignore_index=True)
# /tmp/ipykernel_301/1128254610.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(temp_df,ignore_index=True)
# ...

# %%
df2.head(10)
# Out:
#                             title release_date  vote_average  vote_count
# 0                   The Godfather   1972-03-14           8.7       17053
# 1        The Shawshank Redemption   1994-09-23           8.7       22826
# 2           The Godfather Part II   1974-12-20           8.6       10332
# 3  Guillermo del Toro's Pinocchio   2022-11-09           8.6         420
# 4               20th Century Girl   2022-10-06           8.6         317
# 5                Schindler's List   1993-12-15           8.6       13524
# 6     Dilwale Dulhania Le Jayenge   1995-10-19           8.6        3979
# 7                   Spirited Away   2001-07-20           8.5       13638
# 8                    12 Angry Men   1957-04-10           8.5        6861
# 9                      Your Name.   2016-08-26           8.5        9290

# %%
df2.size
# Out:
# 42240

# %%
df2.shape
# Out:
# (10560, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of                              title release_date  vote_average  vote_count
# 0                    The Godfather   1972-03-14           8.7       17053
# 1         The Shawshank Redemption   1994-09-23           8.7       22826
# 2            The Godfather Part II   1974-12-20           8.6       10332
# 3   Guillermo del Toro's Pinocchio   2022-11-09           8.6         420
# 4                20th Century Girl   2022-10-06           8.6         317
# 5                 Schindler's List   1993-12-15           8.6       13524
# 6      Dilwale Dulhania Le Jayenge   1995-10-19           8.6        3979
# 7                    Spirited Away   2001-07-20           8.5       13638
# 8                     12 Angry Men   1957-04-10           8.5        6861
# 9                       Your Name.   2016-08-26           8.5        9290
# 10        Dou kyu sei – Classmates   2016-02-20           8.5         273
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                              title release_date  vote_average  vote_count
# 0                    The Godfather   1972-03-14           8.7       17053
# 1         The Shawshank Redemption   1994-09-23           8.7       22826
# 2            The Godfather Part II   1974-12-20           8.6       10332
# 3   Guillermo del Toro's Pinocchio   2022-11-09           8.6         420
# 4                20th Century Girl   2022-10-06           8.6         317
# 5                 Schindler's List   1993-12-15           8.6       13524
# 6      Dilwale Dulhania Le Jayenge   1995-10-19           8.6        3979
# 7                    Spirited Away   2001-07-20           8.5       13638
# 8                     12 Angry Men   1957-04-10           8.5        6861
# 9                       Your Name.   2016-08-26           8.5        9290
# 10        Dou kyu sei – Classmates   2016-02-20           8.5         273
# ...

# %%
df.isnull().sum()
# Out:
# title           0
# release_date    0
# vote_average    0
# vote_count      0
# dtype: int64
